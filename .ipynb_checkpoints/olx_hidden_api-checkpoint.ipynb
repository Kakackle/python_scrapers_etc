# %%
import requests
import pandas as pd

# %% [markdown]
# ### URLs

# %%
lookup_term = 'mario'
url_long = f"https://www.olx.pl/api/v1/offers/?offset=0&limit=40&query={lookup_term}\
&filter_refiners=spell_checker&suggest_filters=true&sl=18a03359d3ax36533304"

url = f"https://www.olx.pl/api/v1/offers/?offset=0&limit=40&query={lookup_term}"

# %% [markdown]
# ### Full request

# %%
payload = {}
headers = {
  'authority': 'www.olx.pl',
  'accept': '*/*',
  'accept-language': 'pl',
  'authorization': 'Bearer 13f071aab678158d264e6b8db870f3c8866c2a4d',
  'cookie': 'laquesissu=451^@posting_success|1^#550^@booking_calendar_date_accept|0^#550^@booking_calendar_date_decline|0; deviceGUID=3b1de2d2-0a9e-44d6-a74f-07c8fdee50c1; auto-extension-info-seen=true; SHOULD_DISPLAY_LISTING_OBS_TOOLTIP=false; OptanonAlertBoxClosed=2023-11-21T12:24:58.435Z; eupubconsent-v2=CP1lvFgP1lvFgAcABBENDgCoAP_AAAAAAAYgg1Nf_X_fb3_j8_58__t0eY1f9_7_v-0zjhfdk-8Nyf_X_L8X_2M7vF16pq4KuR4ku3bBIQVlHOHcDUmw6okVrTPsbk2Mr7NKJ7PEmlMbc2dYGH9_n9XT-ZKY79_vf__7__-____9_____-__3_vp__-_2_f_V_cgQAAAAAAAAAAAAAAQAAAAAAAAAQAIAAAAAAAAAAAAAAAAAAAAF_..._ACEgEMARIAjgBLACaAFKALcAYAAw4BkAGWANkAc8A7gDvgHsAfEA-wD9gH-AgABFICLgIwARoAkoBKYCfgKDAU8BVwC5gF6AMUAaIA1gBtADcAHEAQ6AiEBHoCRAE7AKHAUeApEBTYC0AFsALkAXeAvMBgwDCQGGwMiAyQBk4DMwGcgM-AaRA1cDWQG3gN1AcFA5EDlQHLhAEYADgASABHAD-...-A6QB1g6DMAAuACgAKgAcgA-AEAALoAYABlADQANQAeQBDAEQAJgAT4AqgCsAFiALgAugBiADMAG8APQAfoBDAESAJYATAAmgBRgClAFiALcAYAAw4BkAGUANEAbIA3wBzwDuAO8Ae0A-wD9AH-ARSAiwCMAEdgJEAkoBKYCfgKCAU-AqICrgFiALQAXOAvIC9AGKANoAbgA4gBzoDpgOoAfYBDoCIQEXgI9ASCAkQBKgCZAE7AKHgUeBSECmgKbAVYAsUBZQC2AFugLgAXIAu0Bd4C8wF9AMGAYSAw0BjADHoGRgZIAycBlQDLAGZgM5AZ8A0SBpAGkgNLAabA1cDWAG3gN1AcXA5IDlQHLkAD4ACAAHgBoAD--AqICrgFoALmAYoA6gCHQETAIvAR6AkQBR4CxQFlALYAXnAyIDJAGTgM5AZ8A0gBrADbwHAEgDAAFwAjgB4AEiANoAdwBAACDgEJAI4AVABKwCYgE2gKTAX-AxYBlgDPAG5AN0AcSA5YB0hSCUAAuACgAKgAcgA-AEEAMAAxgBoAGoAPIAhgCIAEwAJ4AVQAsABiADMAH6AQwBEgCjAFKALEAW4AwIBkAGUANEAbIA5wB3wD8AP0AiwBGACOwEiASUAlIBQYCogKuAXMAvIBigDaAG4AOoAe0A-wCHQETAIvAR6AkQBOwChwFIAKbAVYAsUBaAC2AFwALkAXaAvMBfQDDQGMQMiAyQBk4DLAGcgM-gaQBpMDWANZAbeA3UBwUDkwOUAcuUAXgA
line_access%22%2C%22audience%22:%22default%22%2C%22redirect_uri%22:%22https://www.olx.pl/d/callback/%22%2C%22state%22:%22MlAxdmRkX2p6SUUyfk12RU5ON05hT0ZDeEFqa0E5Vlo4TVAwMEJHUHVONQ==%22%2C%22appState%22:{%22backUrl%22:%22/d/mojolx%22}}; onap=18a03359d3ax36533304-50-18bfc8e5e44x130c188c-28-1700751650; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Nov+23+2023+15%3A31%3A19+GMT%2B0100+(Central+European+Standard+Time)&version=202307.1.0&isIABGlobal=false&hosts=&genVendors=V10%3A0%2C&consentId=fe9cbb48-5525-4a66-85ec-94062048f40f&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2Cgad%3A1%2CC0004%3A1&geolocation=PL%3B10&AwaitingReconsent=false&browserGpcFlag=0; session_start_date=1700751679684',
  'referer': 'https://www.olx.pl/oferty/q-mario/',
  'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
  'x-client': 'DESKTOP',
  'x-device-id': '3b1de2d2-0a9e-44d6-a74f-07c8fdee50c1',
  'x-fingerprint': '...',
  'x-platform-type': 'mobile-html5'
}

response = requests.request("GET", url, headers=headers, data=payload)
# print(response.text)
# Out:
# {"data":[{"id":871183713,"url":"https://www.olx.pl/d/oferta/tor-wyscigowy-carrera-mario-CID88-IDVXoGd.html","title":"Tor wy\u015bcigowy Carrera Mario","last_refresh_time":"2023-11-23T00:24:16+01:00","created_time":"2023-10-20T22:47:21+02:00","valid_to_time":"2023-12-19T22:47:21+01:00","pushup_time":"2023-11-23T00:24:16+01:00","omnibus_pushup_time":"2023-11-23T00:24:16+01:00","description":"Tor wy\u015bcigowy Carrera Mario \u003Cbr /\u003E\nProdukt powystawowy kompletny, sprawny. W wersji outletowej (jeden ludzik w autku ma doklejon\u0105 g\u0142ow\u0119)\u003Cbr /\u003E\n80 z\u0142(Cena katalogowa 155 z\u0142)\u003Cbr /\u003E\nW razie pyta\u0144 prosz\u0119 o wiadomo\u015b\u0107 \u003Cbr /\u003E\nZdj\u0119cie przedstawia realny stan","promotion":{"highlighted":true,"urgent":false,"top_ad":true,"options":["bundle_optimum"],"b2c_ad_page":false,"premium_ad_page":false},"params":[{"key":"state","name":"Stan","type":"select","value":{"key":"used","label":"U\u017cywane"}},{"key":"price","n
# ...

# %% [markdown]
# ### Minimal working request

# %%
import requests

url = "https://www.olx.pl/api/v1/offers/?offset=0&limit=40&query=pikmin"

payload = {}
headers = {
  'authority': 'www.olx.pl',
  'accept': '*/*',
  'accept-language': 'pl',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'Cookie': 'PHPSESSID=na9stflkrvg4cp638slrnracqi'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":[{"id":879179516,"url":"https://www.olx.pl/d/oferta/pikmin-4-nintendo-switch-CID99-IDXuVKM.html","title":"Pikmin 4 Nintendo Switch","last_refresh_time":"2023-11-22T13:11:12+01:00","created_time":"2023-11-22T13:09:06+01:00","valid_to_time":"2023-12-22T13:11:12+01:00","pushup_time":null,"description":"Gra Pikmin 4 na Nintendo switch dziala pude\u0142ko jak nowe cena nie do negocjacji..","promotion":{"highlighted":false,"urgent":false,"top_ad":false,"options":[],"b2c_ad_page":false,"premium_ad_page":false},"params":[{"key":"price","name":"Cena","type":"price","value":{"value":155,"type":"price","arranged":false,"budget":false,"currency":"PLN","negotiable":true,"converted_value":null,"previous_value":null,"converted_previous_value":null,"converted_currency":null,"label":"155 z\u0142"}},{"key":"type","name":"Platforma","type":"checkboxes","value":{"key":["nintendo-switch"],"label":"Nintendo Switch"}},{"key":"state","name":"Stan","type":"select","value":{"key":"used","label":"U\u01
# ...

# %%
json_data = response.json()

# print(json_data)

# %%
json_data['data'][0]
# Out:
# {'id': 871183713,
#  'url': 'https://www.olx.pl/d/oferta/tor-wyscigowy-carrera-mario-CID88-IDVXoGd.html',
#  'title': 'Tor wyścigowy Carrera Mario',
#  'last_refresh_time': '2023-11-23T00:24:16+01:00',
#  'created_time': '2023-10-20T22:47:21+02:00',
#  'valid_to_time': '2023-12-19T22:47:21+01:00',
#  'pushup_time': '2023-11-23T00:24:16+01:00',
#  'omnibus_pushup_time': '2023-11-23T00:24:16+01:00',
#  'description': 'Tor wyścigowy Carrera Mario <br />\nProdukt powystawowy kompletny, sprawny. W wersji outletowej (jeden ludzik w autku ma doklejoną głowę)<br />\n80 zł(Cena katalogowa 155 zł)<br />\nW razie pytań proszę o wiadomość <br />\nZdjęcie przedstawia realny stan',
#  'promotion': {'highlighted': True,
#   'urgent': False,
#   'top_ad': True,
#   'options': ['bundle_optimum'],
#   'b2c_ad_page': False,
#   'premium_ad_page': False},
#  'params': [{'key': 'state',
#    'name': 'Stan',
#    'type': 'select',
#    'value': {'key': 'used', 'label': 'Używane'}},
#   {'key': 'price',
# ...

# %% [markdown]
# ### Extracting values

# %%
price_label = json_data['data'][0]['params'][1]['value']['label']
price_value = json_data['data'][0]['params'][1]['value']['value']
price_currency = json_data['data'][0]['params'][1]['value']['currency']
used = json_data['data'][0]['params'][0]['value']['label']
title = json_data['data'][0]['title']
url = json_data['data'][0]['url']
id = json_data['data'][0]['id']
description = json_data['data'][0]['description']

# %%
listing_data = []
for p in data['data']:
    listing_data.append({
        title: p['title'],
        url: p['url'],
        description: p['description'],
        id: p['id']
        # price_value: p['params'][1]['value']['value'],
    })
print(len(listing_data))
# Out:
# 52

# %% [markdown]
# ### Saving the results to pandas then csv

# %%
import json

# json_object = json.loads(json_data)

json_formatted_str = json.dumps(json_data, indent=2)

print(json_formatted_str)
# Out:
# {
#   "data": [
#     {
#       "id": 871183713,
#       "url": "https://www.olx.pl/d/oferta/tor-wyscigowy-carrera-mario-CID88-IDVXoGd.html",
#       "title": "Tor wy\u015bcigowy Carrera Mario",
#       "last_refresh_time": "2023-11-23T00:24:16+01:00",
#       "created_time": "2023-10-20T22:47:21+02:00",
#       "valid_to_time": "2023-12-19T22:47:21+01:00",
#       "pushup_time": "2023-11-23T00:24:16+01:00",
#       "omnibus_pushup_time": "2023-11-23T00:24:16+01:00",
#       "description": "Tor wy\u015bcigowy Carrera Mario <br />\nProdukt powystawowy kompletny, sprawny. W wersji outletowej (jeden ludzik w autku ma doklejon\u0105 g\u0142ow\u0119)<br />\n80 z\u0142(Cena katalogowa 155 z\u0142)<br />\nW razie pyta\u0144 prosz\u0119 o wiadomo\u015b\u0107 <br />\nZdj\u0119cie przedstawia realny stan",
#       "promotion": {
#         "highlighted": true,
#         "urgent": false,
#         "top_ad": true,
#         "options": [
#           "bundle_optimum"
#         ],
# ...

# %%
df_listings = pd.json_normalize(listing_data)
df_raw = pd.json_normalize(json_data)

df_listings.to_csv(f'{lookup_term}_listings.csv')
df_raw.to_csv(f'{lookup_term}_raw.csv')
