# %%
import pandas as pd

# %%
path = r'../scraping_results/'
django_scrap = pd.read_csv(path + 'careerjet_pracuj_django_2023-11-27.csv', index_col = 0)
python_scrap = pd.read_csv(path + 'careerjet_pracuj_python_2023-11-25.csv', index_col = 0)

# %%
django_scrap.head()
# Out:
#                                                title  \
# 0                                 Principal Engineer
# 1   Mid / Senior Embedded C Developer @ Antal Poland
# 2                   Senior Data Engineer with Python
# 3          Senior Backend Software Engineer (Python)
# 4  Software Engineer Graduate/Junior/Mid-level/Se...
#
#                                                 link              company  \
# 0  careerjet.pl/jobad/ple024624de54a7ab6cd00faaa5...      GlaxoSmithKline
# 1  careerjet.pl/jobad/pl61983754038c9fd7fabcf22f3...  Antal International
# 2  careerjet.pl/jobad/plec2c01a7de163b1feea09fbb6...     GFT Technologies
# 3  careerjet.pl/jobad/pl905e92585e2c168426fc9d00d...             Binariks
# 4  careerjet.pl/jobad/pl96d8d973cc51f6d96a07f961d...      Arista Networks
#
#                 location salary  \
# 0  Poznań, wielkopolskie    NaN
# 1    Kraków, małopolskie    NaN
# 2                 Polska    NaN
# 3    Kraków, małopolskie    NaN
# ...

# %%
python_scrap.head()
# Out:
#                                          title  \
# 0  Climate Risk - Regulatory Reporting Analyst
# 1                            analityk big data
# 2                       Software Test Engineer
# 3                       Senior DevOps Engineer
# 4              Senior Test Automation Engineer
#
#                                                 link    company  \
# 0  careerjet.pl/jobad/plf5c63585be33eed77ba668c07...  Citigroup
# 1  careerjet.pl/jobad/pla642499eec94e311324e64bbe...  Santander
# 2  careerjet.pl/jobad/pl798a9ca8cf8affde11c0eaa00...     Harman
# 3  careerjet.pl/jobad/pl3ee93a7b0e2e7e038e538e5e2...     Luxoft
# 4  careerjet.pl/jobad/pl6c1316b98726ba2a26939895d...     Luxoft
#
#                 location salary  \
# 0  Warszawa, mazowieckie    NaN
# 1  Warszawa, mazowieckie    NaN
# 2          Łódź, łódzkie    NaN
# 3  Wrocław, dolnośląskie    NaN
# 4  Warszawa, mazowieckie    NaN
#
#                                          description  date_added skills  \
# ...

# %%
print(django_scrap.shape)
print(python_scrap.shape)
# Out:
# (83, 10)
# (350, 10)

# %%
combined = pd.concat([python_scrap, django_scrap])
combined.shape
# Out:
# (433, 10)
