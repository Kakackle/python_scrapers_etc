# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### load data and clean any nulls

# %%
data_pd_raw = pd.read_csv('./seinfeld_pd.csv', index_col=0)
data_pd_raw.dropna()
# Out:
#                                                 title  price   used  \
# 0                       Lego Zestaw Nr 21328 Seinfeld    250   True
# 1                                 Lego 21328 Seinfeld    240  False
# 2                                 Lego Seinfeld 21328    240   True
# 3                    Funko Pop Seinfeld 1096 Jerry #3     35  False
# 4        Funko Pop Seinfeld 1094 George (Holistic) #2     40  False
# 5        Funko Pop Seinfeld 1094 George (Holistic) #1     40  False
# 6                    Funko Pop Seinfeld 1096 Jerry #3     35  False
# 7                    Funko Pop Seinfeld 1096 Jerry #2     35  False
# 8                           LEGO Ideas 21328 Seinfeld    250  False
# 9                         Lego 21328 Seinfeld OKAZJA!    220  False
# 10                      Seinfeld DVD wszystkie sezony    380   True
# 11                          Lego Ideas 21328 Seinfeld    350  False
# 12                     Nowe LEGO 21328 Ideas Seinfeld    320  False
# 13                                Lego Seinfeld 21328    280  False
# 14              LEGO 21328 Ideas - Seinfeld nowy MISB    299  False
# 15          DJ Seinfeld – Ruff Hysteria , natural 009     30   True
# 16                          LEGO Ideas 21328 Seinfeld    285  False
# 17                        Ideas - Seinfeld 21328 Lego    300  False
# 18        DJ Seinfeld – Sunrise\nEndotherm – ENDOS001     30   True
# 19                     LEGO Technic 42126 Ford Raptor    570  False
# 20                     Funko pop Elaine Seinfeld 1083     60  False
# 21                          LEGO ideas 21328 Seinfeld    200   True
# 22  Funko Pop! - Seinfeld - Kramer With Sandwitch ...     35  False
# 23                lego Ideas 21328 z serialu Seinfeld    220   True
# 24                 Is this anything? - Jerry Seinfeld    100   True
# 25           Nowe LEGO 21328 Ideas - Seinfeld Kroniki    300  False
# 26               Figurka Funko Pop, Kramer (Seinfeld)     40  False
# 27                          Lego ideas 21328 SEINFELD    230  False
# 28                   Klocki LEGO Ideas Seinfeld 21328    300  False
# 29           Nowa instrukcja i naklejki LEGO Seinfeld     40  False
# 30  Nimrod (vinyl) - Green Day, 25th Anniversary D...    500  False
# 31      Figurka Funko Pop, Kramer, Good cop, Seinfeld     45  False
# 32              Lego Figurka z Zestawu 21328 Seinfeld     15   True
# 33  LEGO 21328stk01 Naklejka z zestawu 21328 SEINFELD      9  False
# 34  Funko POP Seinfeld Kramer (good cop) figurka n...     40   True
# 35         Lego 75336 transporter inkwizytorów scythe    479  False
# 36  Klocki Lego 21328 Seinfeld nowe szybka wysyłka...    399   True
# 37  Figurka Funko Pop 1092 KRAMER (GOLF) Seinfeld ...     39  False
# 38                                Lego 10271 Fiat 500    480  False
# 39              Funko POP Kramer (Golf) 1092 Seinfeld     55  False
#
#                         city                  date  shipping  \
# 0         Warszawa, Targówek     02 listopada 2023     False
# 1          Warszawa, Mokotów     10 listopada 2023     False
# 2             Warszawa, Wola     16 listopada 2023      True
# 3                     Brzana     16 listopada 2023      True
# 4                     Brzana     16 listopada 2023      True
# 5                     Brzana     16 listopada 2023      True
# 6                     Brzana     16 listopada 2023      True
# 7                     Brzana     16 listopada 2023      True
# 8             Warszawa, Wola     03 listopada 2023     False
# 9                     Orzech  31 października 2023     False
# 10        Warszawa, Żoliborz     12 listopada 2023      True
# 11          Kraków, Podgórze     11 listopada 2023      True
# 12    Białystok, Nowe Miasto     17 listopada 2023      True
# 27  olx.pl/d/oferta/lego-ideas-21328-seinfeld-CID8...
# 28  olx.pl/d/oferta/klocki-lego-ideas-seinfeld-213...
# 29  olx.pl/d/oferta/nowa-instrukcja-i-naklejki-leg...
# 30  olx.pl/d/oferta/nimrod-vinyl-green-day-25th-an...
# 31  olx.pl/d/oferta/figurka-funko-pop-kramer-good-...
# 32  olx.pl/d/oferta/lego-figurka-z-zestawu-21328-s...
# 33  olx.pl/d/oferta/lego-21328stk01-naklejka-z-zes...
# 34  olx.pl/d/oferta/funko-pop-seinfeld-kramer-good...
# 35  olx.pl/d/oferta/lego-75336-transporter-inkwizy...
# 36  olx.pl/d/oferta/klocki-lego-21328-seinfeld-now...
# 37  olx.pl/d/oferta/figurka-funko-pop-1092-kramer-...
# 38  olx.pl/d/oferta/lego-10271-fiat-500-CID88-IDVX...
# 39  olx.pl/d/oferta/funko-pop-kramer-golf-1092-sei...

# %%
print(f'columns: {data_pd_raw.columns}')
# Out:
# columns: Index(['title', 'price', 'used', 'city', 'date', 'shipping', 'link'], dtype='object')

# %% [markdown]
# ### Drop non-seinfeld data

# %%
# non_sein = data_pd.loc[~data_pd['title'].str.contains('seinfeld', case=False)]
data_pd = data_pd_raw.loc[data_pd_raw['title'].str.contains('seinfeld', case=False)]

# %% [markdown]
# ### Split into categories

# %%
# 3 categories we're interested in
lego_rows = data_pd.loc[data_pd['title'].str.contains('lego', case=False)]
funko_rows = data_pd.loc[data_pd['title'].str.contains('funko', case=False)]
dvd_rows = data_pd.loc[data_pd['title'].str.contains('dvd', case=False)]

# %% [markdown]
# ### explore lego prices spread

# %%
lego_prices = lego_rows['price']
lego_prices_hist = lego_prices.hist()

# %%
print(lego_prices.describe())
# Out:
# count     20.000000
# mean     237.350000
# std      104.688146
# min        9.000000
# 25%      220.000000
# 50%      250.000000
# 75%      300.000000
# max      399.000000
# Name: price, dtype: float64

# %%
plt.show()

# %% [markdown]
# ### [LEGO] - cut off low prices, filter by city or with shipping

# %%
my_city = 'łódź'

# %%
filtered_lego = lego_rows.loc[lego_rows['price'].gt(100)
                                & ( lego_rows['city'].str.contains(my_city, case=False)
                                   | lego_rows['shipping'] == True
                                   )]

# %%
print('filtered lego')
print(filtered_lego.describe())
# Out:
# filtered lego
#             price
# count    9.000000
# mean   288.222222
# std     63.322148
# min    200.000000
# 25%    240.000000
# 50%    285.000000
# 75%    320.000000
# max    399.000000

# %% [markdown]
# ### Split between new and used sets

# %%
filtered_new = filtered_lego.loc[filtered_lego['used'] == False]
filtered_used = filtered_lego.loc[filtered_lego['used'] == True]

# %%
print(filtered_new.count())
print(filtered_used.count())
# Out:
# title       5
# price       5
# used        5
# city        5
# date        5
# shipping    5
# link        5
# dtype: int64
# title       4
# price       4
# used        4
# city        4
# date        4
# shipping    4
# link        4
# dtype: int64

# %% [markdown]
# #### Is there a perfect match (in Lodz)

# %%
print(filtered_lego.loc[filtered_lego['city'].str.contains(my_city, case=False)].any())
# Out:
# title       False
# price       False
# used        False
# city        False
# date        False
# shipping    False
# link        False
# dtype: bool

# %% [markdown]
# ### Min. price in new sets

# %%
min_filtered_price = filtered_new[filtered_new['price'] == filtered_new['price'].max()]
print(min_filtered_price)

# %%
# filtered_lego.plot()
# Out:
# <Axes: >
